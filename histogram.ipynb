# %% [markdown]
# <a href="https://colab.research.google.com/github/annapureddypravallika/datascience-tutorial/blob/main/histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[70,50,100,70,50,100,50,50,50,70,50]
plt.hist(x,orientation="vertical")
plt.title("mark analysis")
plt.ylabel("no.of students")
plt.xlabel("marks")
plt.show()
